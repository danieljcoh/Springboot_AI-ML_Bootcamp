# %% [markdown]
# # Capstone Project: Pokemon Match-Victory Predictor

# %%
import pandas as pd

# %%
pokemon_df = pd.read_csv('capstone_datasets/pokemon.csv')
battles_df = pd.read_csv('capstone_datasets/combats.csv')

# %%
pokemon_df.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
battles_df.head()
# Out:
#    First_pokemon  Second_pokemon  Winner
# 0            266             298     298
# 1            702             701     701
# 2            191             668     668
# 3            237             683     683
# 4            151             231     151

# %%
pokemon_df.isna().sum()
# Out:
# #               0
# Name            1
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
pokemon_df[pokemon_df['Name'].isna()]
# Out:
#      # Name    Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 62  63  NaN  Fighting    NaN  65     105       60       60       70     95
#
#     Generation  Legendary
# 62           1      False

# %%
pokemon_df.loc[62, 'Name'] = 'Primeape'

# %%
pokemon_df.isna().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
pokemon_df[pokemon_df['Name'] == 'Primeape']
# Out:
#      #      Name    Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 62  63  Primeape  Fighting    NaN  65     105       60       60       70
#
#     Speed  Generation  Legendary
# 62     95           1      False

# %%
battles_df.isna().sum()
# Out:
# First_pokemon     0
# Second_pokemon    0
# Winner            0
# dtype: int64

# %%
combined = pokemon_df.merge(battles_df, left_on='#', right_on='First_pokemon')
combined.head(20)
# Out:
#     #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0   1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1   1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2   1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 3   1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 4   1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 5   1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 6   1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 7   1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 8   1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 9   1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 10  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# ...

# %%
matches_df = battles_df.merge(pokemon_df, left_on='First_pokemon', right_on='#')
matches_df.head()
# Out:
#    First_pokemon  Second_pokemon  Winner    #      Name Type 1    Type 2  HP  \
# 0            266             298     298  266  Larvitar   Rock    Ground  50
# 1            702             701     701  702  Virizion  Grass  Fighting  91
# 2            191             668     668  191   Togetic  Fairy    Flying  55
# 3            237             683     683  237    Slugma   Fire       NaN  40
# 4            151             231     151  151   Omastar   Rock     Water  70
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0      64       50       45       50     41           2      False
# 1      90       72       90      129    108           5       True
# 2      40       85       80      105     40           2      False
# 3      40       40       70       40     20           2      False
# 4      60      125      115       70     55           1      False

# %%
final_matches_df = matches_df.merge(pokemon_df, left_on='Second_pokemon', right_on='#', suffixes=('_p1', '_p2'))
final_matches_df.head(10)
# Out:
#    First_pokemon  Second_pokemon  Winner  #_p1   Name_p1 Type 1_p1 Type 2_p1  \
# 0            266             298     298   266  Larvitar      Rock    Ground
# 1            702             701     701   702  Virizion     Grass  Fighting
# 2            191             668     668   191   Togetic     Fairy    Flying
# 3            237             683     683   237    Slugma      Fire       NaN
# 4            151             231     151   151   Omastar      Rock     Water
# 5            657             752     657   657    Joltik       Bug  Electric
# 6            192             134     134   192      Natu   Psychic    Flying
# 7             73             545     545    73    Machop  Fighting       NaN
# 8            220             763     763   220    Pineco       Bug       NaN
# 9            302              31      31   302   Wingull     Water    Flying
#
#    HP_p1  Attack_p1  Defense_p1  ...  Type 1_p2  Type 2_p2  HP_p2  Attack_p2  \
# ...

# %%
final_matches_df.columns
# Out:
# Index(['First_pokemon', 'Second_pokemon', 'Winner', '#_p1', 'Name_p1',
#        'Type 1_p1', 'Type 2_p1', 'HP_p1', 'Attack_p1', 'Defense_p1',
#        'Sp. Atk_p1', 'Sp. Def_p1', 'Speed_p1', 'Generation_p1', 'Legendary_p1',
#        '#_p2', 'Name_p2', 'Type 1_p2', 'Type 2_p2', 'HP_p2', 'Attack_p2',
#        'Defense_p2', 'Sp. Atk_p2', 'Sp. Def_p2', 'Speed_p2', 'Generation_p2',
#        'Legendary_p2'],
#       dtype='object')
